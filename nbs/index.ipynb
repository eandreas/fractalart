# %%
#| hide
from fractalart.core import *
from fractalart.fractal import *

# %% [markdown]
# # fractalart
#
# > Generative art based on fractals

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install fractalart in Development mode

# %% [markdown]
# ```sh
# # make sure fractalart package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to fractalart
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/eandreas/fractalart.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c eandreas fractalart
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install fractalart
# ```
#
#
# [repo]: https://github.com/eandreas/fractalart
# [docs]: https://eandreas.github.io/fractalart/
# [pypi]: https://pypi.org/project/fractalart/
# [conda]: https://anaconda.org/eandreas/fractalart

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/eandreas/fractalart
# [docs]: https://eandreas.github.io/fractalart/
# [pypi]: https://pypi.org/project/fractalart/
# [conda]: https://anaconda.org/eandreas/fractalart

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2

# %%
m = Julia(cr = -0.7, ci = 0.27015)

# %%
m.render()
m.equalize_histogram()

# %%
m.plot()
